# %%
with open("in.txt", 'r') as f:
    board = f.read()
print(board)

with open("in.txt", 'r') as f:
    data = f.read().splitlines()
print(data)
print(len(data))

board = []
for row in data:
    r = []
    for col in row:
        r.append(col)
    board.append(r)
print(board)
# Out:
# #############################################################################################################################################
# #...........#.......#.........#.........#.........#.............#...........#...#.......#.....#.......#.......#.......#.....#.........#....E#
# #.#########.#####.#.#######.#.###.#.###.#.#####.###.#.#########.#.#.#######.#.#.#####.#.###.#.#.#####.#.#.###.#####.#.#.###.#.#######.#.###.#
# #.............#...#.........#...#.#.#.....#...#.#...#.#.......#...#.#.....#...#.......#...#.........#.#.#...#.......#...#...#...#...#.#...#.#
# #########.###.#.###.#######.###.#.#.#.#####.#.#.#.###.#.#########.#.#.###.###########.###.#.#######.#.#####.###########.#.###.#.#.#.#.#.#.#.#
# #.......#.#...#...#.#...#.....#.#.#.#.#...#.#...#...#.#.........#.#.#.....................#.....#...#...................#...#.#.#.#.#.#.#.#.#
# ...

# %%
directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]
map_directions = [">", "v", "<", "^"]

def turn(direction_idx, turn):
    if turn == "R":
        return (direction_idx + 1) % len(directions)
    else:
        if direction_idx == 0:
            return len(directions) - 1
        return direction_idx - 1

# %%
bfs_valid_paths_values = []

# %%
from collections import deque
#(x,y,direction_idx,(steps, rotations, points))
queue = deque()
# visited = set([])
d_visited = {}
queue.append([len(board) - 2, 1, 0, (0,0), set([])])
rotate = [0,1,2,1]
vals = [0,1000,2000,1000]
res = []
i = 0
while queue:
    i += 1
    x,y,direction_idx,(steps, rotations), points = queue.pop()
    # c = queue.popleft()
    # print(c)
    # print(x,y,direction_idx,steps,rotations)

    # visited.add((x,y))
    d_visited[(x,y)] = (steps + 1000 * rotations)
    for r in range(4):
        rot = rotate[r]
        act_dir = (direction_idx + r)%4
        direction = directions[act_dir]
        next_x, next_y = x + direction[0], y + direction[1]
        # print(next_x, next_y)
        val = steps+1 + ((rotations + rot)*1000)
        n_points = points.copy()
        n_points.add((next_x,next_y))
        if board[next_x][next_y] == "." and (next_x, next_y):
            if (next_x, next_y) not in points and val < 83444:
                # d_visited[(next_x, next_y)] = val

                queue.append((next_x, next_y, act_dir, (steps + 1, rotations + rot), n_points))
        elif board[next_x][next_y] == "E":

            res.append((steps + 1, rotations + rot, points))
    if i > 100000000:
        break

# %%
print(res)
print(i)

x = [steps + rotations*1000 for steps, rotations, points in res]
y = [(steps + rotations*1000, points) for steps, rotations, points in res]
print(x)
minimum = min(x)

print(min(x))

res_set = set([])
for steps, points in y:
    if steps == minimum:
        res_set = res_set.union(points)

print(len(res_set) + 2)
# Out:
# []
# 100000001
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 7
#       5 y = [(steps + rotations*1000, points) for steps, rotations, points in res]
#       6 print(x)
# ----> 7 minimum = min(x)
#       9 print(min(x))
#      11 res_set = set([])
#
# ValueError: min() iterable argument is empty
